# %%
### Roger Valdez
### ISQS 6337: Scripting Languages
### Data Analysis Project Due: 10-11-2018
### Weather Data from World War II: 1940-1945
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style

# %%
### Weather Temperature Data
weatherdata=pd.read_csv('Summary of Weather.csv')
weatherdata.head(10)
# Out:
# C:\Users\Roger Valdez III\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      STA       Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 0  10001   1942-7-1  1.016          NaN  25.555556  22.222222  23.888889
# 1  10001   1942-7-2      0          NaN  28.888889  21.666667  25.555556
# 2  10001   1942-7-3   2.54          NaN  26.111111  22.222222  24.444444
# 3  10001   1942-7-4   2.54          NaN  26.666667  22.222222  24.444444
# 4  10001   1942-7-5      0          NaN  26.666667  21.666667  24.444444
# 5  10001   1942-7-6      0          NaN  26.666667  21.666667  24.444444
# 6  10001   1942-7-7      T          NaN  28.333333  22.777778  25.555556
# 7  10001   1942-7-8  3.556          NaN  26.666667  22.222222  24.444444
# ...

# %%
### Drop data
weatherdata = weatherdata.drop(['Precip','Snowfall','STA','Date','WindGustSpd','PoorWeather',"PRCP",'DR','SPD','MaxTemp', 'MinTemp','MeanTemp', 'SNF', 'SND', 'FT', 'FB', 'FTI', 'ITH', 'PGT', 'TSHDSBRSGF', 'SD3', 'RHX', 'RHN', 'RVG', 'WTE'], axis=1)
weatherdata.head(30)
# Out:
#     YR  MO  DA   MAX   MIN   MEA
# 0   42   7   1  78.0  72.0  75.0
# 1   42   7   2  84.0  71.0  78.0
# 2   42   7   3  79.0  72.0  76.0
# 3   42   7   4  80.0  72.0  76.0
# 4   42   7   5  80.0  71.0  76.0
# 5   42   7   6  80.0  71.0  76.0
# 6   42   7   7  83.0  73.0  78.0
# 7   42   7   8  80.0  72.0  76.0
# 8   42   7   9  81.0  73.0  77.0
# 9   42   7  10  78.0  71.0  74.0
# 10  42   7  11  78.0  71.0  74.0
# 11  42   7  12  76.0  72.0  74.0
# 12  42   7  13  79.0  71.0  75.0
# 13  42   7  14  79.0  72.0  76.0
# 14  42   7  15  78.0  73.0  76.0
# 15  42   7  16  79.0  70.0  74.0
# 16  42   7  17  83.0  72.0  78.0
# 17  42   7  18  80.0  70.0  75.0
# 18  42   7  19  82.0  71.0  76.0
# 19  42   7  20  79.0  68.0  74.0
# 20  42   7  21  76.0  71.0  74.0
# 21  42   7  22  76.0  70.0  73.0
# 22  42   7  23  80.0  69.0  74.0
# 23  42   7  24  81.0  66.0  74.0
# 24  42   7  25  81.0  67.0  74.0
# 25  42   7  26  78.0  67.0  72.0
# 26  42   7  27  78.0  67.0  73.0
# ...

# %%
### What were the weather conditions during World War II?

# %%
### Use qqplot style
style.use('ggplot')

### Scatter plot for MaxTemp and MinTemp fitting a regression line
sns.regplot('MAX','MIN', data=weatherdata).set_title('Max and Min Temperature')
# Out:
# Text(0.5,1,'Max and Min Temperature')

# %%
### Scatterplot with varying point sizes
sns.relplot(x='MO',y='MIN',size='MAX',data=weatherdata)
plt.show()

# %%
### Scatter plot 
fig, ax = plt.subplots(1,2,figsize=(12,6))
sns.boxplot(x='YR',y='MEA', data=weatherdata,ax=ax[0])
sns.boxplot(x='MO',y='MEA', data=weatherdata,ax=ax[1])
plt.show()

# %%
### Weather Station Location
weatherlocation=pd.read_csv('Weather Station Locations.csv')
weatherlocation.head(10)
# Out:
#     WBAN                     NAME STATE/COUNTRY ID    LAT     LON  ELEV  \
# 0  33013                   AIN EL               AL  3623N  00637E   611
# 1  33031                 LA SENIA               AL  3537N  00037E    88
# 2  33023           MAISON BLANCHE               AL  3643N  00314E    23
# 3  33044                 TELERGMA               AL  3607N  00621E   754
# 4  12001                  TINDOUF               AL  2741N  00809W   443
# 5  11604  ST JOHNS/COOLIDGE FIELD               AT  1707N  06147W    10
# 6  82502                  AMBERLY               AU  2736S  15243E    27
# 7  82501                   ARCHER               AU  2735S  15301E    19
# 8  82506                 BRISBANE               AU  2726S  15305E     2
# 9  82402              CHARLEVILLE               AU  2625S  14616E   300
#
#     Latitude   Longitude
# 0  36.383333    6.650000
# 1  35.616667    0.583333
# 2  36.716667    3.216667
# 3  36.116667    6.416667
# 4  27.683333   -8.083333
# ...

# %%
weatherlocation=weatherlocation.drop(['WBAN','LAT','LON',],axis=1)
plt.figure(figsize=(22,10))
sns.countplot(weatherlocation['STATE/COUNTRY ID'])
plt.xticks(rotation=90)
plt.show()
#Italy, France, Hawaii, Australia, Panama
